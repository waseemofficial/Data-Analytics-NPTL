# %%
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup

url= "https://prod--api.educationdatahub.dsti.gov.sl/schools/2019"
r =requests.get(url)
soup=BeautifulSoup(r.content)

p=soup.find_all("p")

# %%
data = r.json()

# %%
school = []

for id in data:
    school.append(id)

# %%
df = pd.json_normalize(school)

# %%
df
# Out:
#         id                                    idschool_name          sch_type  \
# 0      513                         Kankalay Islamic Primary           Primary
# 1      514                  Kankalay Islamic Primary Malema           Primary
# 2      515                                     Kldec School           Primary
# 3      516  Lamin Wacendahs Islamic Junior Secondary School  Junior Secondary
# 4      517                                Methodist Primary           Primary
# ...    ...                                              ...               ...
# 11175  508                   Ansarul Islamic Primary School           Primary
# 11176  509                                Community Primary           Primary
# 11177  510            Community Vocational Junior Secondary  Junior Secondary
# 11178  511        Kailahun Destrict Council Council Primary           Primary
# 11179  512              Kailahun District Education Primary           Primary
#
# ...

# %%
df.to_csv("school_names.csv")
