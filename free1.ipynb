# %%
import pandas as pd
import numpy as np
import matplotlib as mlp

# %%
data = pd.read_excel("Book1.xlsx",index_col="contries")
data.head(10)
# Out:
#            € Cost per install  \
# contries
# Country1                   10
# Country2                    9
# Country3                    6
# Country4                    8
# Country5                    7
# Country6                    9
# Country7                    6
# Country8                    6
# Country9                    4
# Country10                   8
#
#            # Maximum number of app installs that Google can offer per month  \
# contries
# Country1                                                1500
# Country2                                                4000
# Country3                                                 500
# Country4                                                1000
# Country5                                                 600
# Country6                                                3000
# Country7                                                1000
# Country8                                                 500
# ...

# %%
data["total app inst in max budget"]=data["€ Maximum investment budget for this campaign per month (Budget)"]/data["€ Cost per install"]
data
# Out:
#            € Cost per install  \
# contries
# Country1                   10
# Country2                    9
# Country3                    6
# Country4                    8
# Country5                    7
# Country6                    9
# Country7                    6
# Country8                    6
# Country9                    4
# Country10                   8
#
#            # Maximum number of app installs that Google can offer per month  \
# contries
# Country1                                                1500
# Country2                                                4000
# Country3                                                 500
# Country4                                                1000
# Country5                                                 600
# Country6                                                3000
# Country7                                                1000
# Country8                                                 500
# ...

# %%
data.plot(figsize=(10,10),xlim=1)
# Out:
# <AxesSubplot:xlabel='contries'>

# %%
data.plot(kind="bar",figsize=(9,9))
# Out:
# <AxesSubplot:xlabel='contries'>
