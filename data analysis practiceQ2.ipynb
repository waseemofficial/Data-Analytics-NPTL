# %%
import numpy as np
import seaborn as sn
from matplotlib import pyplot as plt
from scipy import stats
import pandas as pd
import statistics

# %% [markdown]
# A national survey suggests that adults sleep an average of 6.8 hours during
# workdays. Adults who routinely get less than 6 hours of sleep have an increased
# risk of depression, memory loss, illness, and reduced job performance. A
# psychologist suspects that women living in low-income households may sleep less
# than the national average. Fifteen women were randomly selected from a
# directory of about 15,000 low-income households in Oakland, CA. Each woman
# was asked to estimate the number of hours slept on a typical workday. The
# number of hours reported by each woman is given below.
#
#  5.5 5.0 6.5 7.0 4.5 6.0 5.0
#
#  7.5 5.0 6.0 8.0 5.0 6.5 5.5 7.0
#
# a) Describe the study population.
#
#
# b) Describe the population mean (𝜇) in the context of this study.
#
# c) Test H0: 𝜇 = 6.8. Report t, df, p-value, and your decision based on 𝛼 = .05. (continued)
# 2
#
# d) Compute a 95% confidence interval for 𝜇 and interpret the results.
#
# e) A similar study is being planned for Dallas. How many low-income women should be
# sampled to obtain a 95% confidence interval for 𝜇 that has a width of 0.5? Use the sample
# variance (squared standard deviation) from this study as the planning value for the
# population variance. Use R or hand compute Equation 1.6.

# %%
pop = 15000
n=15
x = [5.5,5.0,6.5,7.0,4.5,6.0,5.0,7.5,5.5,6.0,8.0,5.0,6.5,5.5,7.0]

# %%
data = pd.DataFrame(x)
data.rename(columns={0:"Hr_sleep"},inplace=True)
data
# Out:
#     Hr_sleep
# 0        5.5
# 1        5.0
# 2        6.5
# 3        7.0
# 4        4.5
# 5        6.0
# 6        5.0
# 7        7.5
# 8        5.5
# 9        6.0
# 10       8.0
# 11       5.0
# 12       6.5
# 13       5.5
# 14       7.0
